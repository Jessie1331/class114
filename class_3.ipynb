# %%
class Queue:
    def __init__(self):
        self.items = []

    def enqueue(self, value):
        self.items.insert(0, value)

    def dequeu(self):
        return self.items.pop()

#nice to have method
    def peek(self):
        return self.items[len(self.items)-1]

     def size(self)
         return len(self.items)

     def is_empty(self):
         return self.items == []

# %%
class QueueII:
    class __Node:
      def __init__(self, data):
          self.data = data
          self.next = None
          # should node track the previouse Node,the next Node or both
          
    def __init__(self):
        #should we track the rear, the front or both?
        self.front = None
        self.rear = None
          pass

     def enqueue(self, value):
         #recives a value and "enqueues" it at the rear
         new_node = self.__Node(value)
         if not self.rear:
             self.rear = self.front = New_node
         else:
             self.rear.next = new_node
     

    def dequeue(self):
        #removes and returns an element at the front
        if not self.front

        pass
#nice to have
    def peek(self):
        #returns, but dose not remove the data at the front node
        pass

    def size(self):
        #returns the totel number of Nodes in then queue
        self = self[len(items.value)]
        return len(self.items)
        pass

    def is_empty(self):
        #returns true when the queue is empty False otherwise
        return self.items == []
    else:
        return self.items >= [0]
        pass

# %%
#linked Lists 
class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None

       def __init__(self):
           self.head = None

       def __str__(self):
           out = "["
           current = self.head
           if current:
               out += ", %s" % current.data
               current = current.next
        while current:
            out += ", %s" % current .data
            current = current.next
        out += "]"
        return out

       def append(self, value):
           new_node = self.__Node(value)
           current = self.head
           if not current:
               self.head = new_node
           else:
               while current.next:
                   current =  current.next
                   current.next = new_node

      def insert(self, index, value):
          new_node = self.__Node(value)
          if not self.head:
              self.head = new_node
          else:
              if index == 0:
                  odl_head = self.head
                  self.head = new_name
                  mew_node.next = old_head
              else:
                  prev = None
                  current = self.head
                  count = 0
                  
      

        while count != index and current:
            prev = current 
            current = current.next
            count +=1
          if count == index:
              prev.next = new_node 
              new_node.next= current
          else:
              current.next = new_node

       
      
   
       def remove(self, value):
           found = False
           if self.head:
               prev = None
               current = self.head
               while current:
                   if current.data == value:
                       found = True
                       break
                       prev = current
                       current = current.next
                       if found:
                           prev.next = current.next
                           if not found:
                               raise ValueError("Value not found")
   


     def index(self, value):
     return self.[]
      def __getitem__(self, index):
          if self.head:
              count = 0 
              current = self.head
              while count != index and current:
                  current = current.next
                  count += 1
                  if count == index
                  return current data
                  raise IndexError("Index out of bpunds")

     def __len__(self):
         count = 0 
         current = self.head
         while current:
             current = current.next
             count +=1
             return count
    def is_empty(self):
        return self.head == None

# %%
pylist = []
sll = SinglyLinkedList()

# when the list is empty:
print("Python list: %s" % pylist)
print("Our SLL: %S" % sll)

  # when list containes exactly one element:
pylist.append(1)
sll.append(1)
print("python list: %s" % pylist)
print("Our SLL: %s" % sll)
# when the list contains more then 1 element:
for number in range(2, 6):
    pylist.append(number)
    sll.append(number)

print("python list: %s" % pylist)
print("Our SLL: %s" % sll)
