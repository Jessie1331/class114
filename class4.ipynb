# %%
class DoublyLinkedList:
    class __Node:
        def __init__ (self, data):
            self.data = data 
            self.next = None 
            self.prev = None

    def __init__(self):
        self.head = None

    def append(self, value):
        new_node = self.__Node(value)
        if not head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
                current.next = new_node
                new_node.prev = current
    def __str__(self):
        out = "["
        current = self.head
        if current:
            out = "%s" % current .data
            current = current.next
            while current:
            out += ", %s" % current.data
            current = current.next
            out += "]"
            return out


    def insert(self, index, value): 
        new _node = self_Node(value)
        if not self.head:
          self head = new_node
        else:
            current = self.head 
            for __in range(index -1):
            if not current:
                break
                current = current.next
                new_node. next = current.next
                new_node.prev = current 
                if current.next:
                    current.next.prev = new_node
                    current.next = new_node
        index = node

    def remove(self, value):
      if self.head is None:
            print("Linked List is empty. Cannot delete elements.")
        elif self.head.next is None:
            self.head = None
        else:
            self.head = self.head.next
            self.head.previous = None

# %%
#factorrials:
# 5! = 5x4x3x2x1

# 0! = 1 <----a base case

# 5! = 5x4!
# 4! = 4x3
# a recursive function is out thatr calls  itself atlest once
# another imp[ortent premise isthat ther must be (at a minimun):
#1. a base case or exist condition
#2 a recrsive case or condition were the function calls itself

#factorial functions as a recusive function:

def fact(n):
    if n == 0:
        return 1 
return n*fact(n-1)
fact(5)

# %%
#fibonacci
#f0 = 0
#f1 = 1
# Fn = Fn-1 + Fn-2

# 0, 1, 1, 2, 3, 5, 8, 13, 21,

#what is fibanacci of 20 
#simple implamentation of HashTable using built in (lru_cache)
from functools import lru_cache

@lru_cache
def fib(n):
    if n < 2:
        return n
        return fib(n-1)+fib(n-2)

fib(50)

# %%
# use a bult in dictionary to improve the profoormance of the fibonacci functiion

#mynewdictionary = {}
# mynewdictionary = dict()

# recive a paramiter N
# if the parameter N matches a key in your dictonary, return the value assocated with the key
#if not call the fibanacci function on N , and store the results befor returning to the caller

def fib2(n)

     if n in mynewdictonary.keys():
    return mynewdictionary(n)
if n <2:
    return n
